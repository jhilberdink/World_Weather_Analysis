# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import requests
from citipy import citipy
import json

# %%
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | nemuro
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | viesca
# Processing Record 4 of Set 1 | san patricio
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | husavik
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | pangoa
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | toma
# Processing Record 19 of Set 1 | chumphon
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | asau
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | shelopugino
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | emba
# Processing Record 34 of Set 1 | yamethin
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | logansport
# Processing Record 38 of Set 1 | richmond
# Processing Record 39 of Set 1 | natal
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | rocha
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | layou
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | karera
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | walvis bay
# Processing Record 48 of Set 1 | lawang
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 52 of Set 2 | nikolskoye
# Processing Record 53 of Set 2 | port alfred
# Processing Record 54 of Set 2 | ponta do sol
# Processing Record 55 of Set 2 | kodiak
# Processing Record 56 of Set 2 | lebu
# Processing Record 57 of Set 2 | busselton
# Processing Record 58 of Set 2 | bubaque
# Processing Record 59 of Set 2 | arroyo
# Processing Record 60 of Set 2 | nouadhibou
# Processing Record 61 of Set 2 | tuktoyaktuk
# Processing Record 62 of Set 2 | boende
# Processing Record 63 of Set 2 | kapaa
# Processing Record 64 of Set 2 | saint anthony
# Processing Record 65 of Set 2 | mont-joli
# Processing Record 66 of Set 2 | tiznit
# Processing Record 67 of Set 2 | hilo
# Processing Record 68 of Set 2 | richards bay
# Processing Record 69 of Set 2 | longyearbyen
# Processing Record 70 of Set 2 | ritchie
# Processing Record 71 of Set 2 | chuy
# Processing Record 72 of Set 2 | bethel
# Processing Record 73 of Set 2 | tura
# Processing Record 74 of Set 2 | bambous virieux
# Processing Record 75 of Set 2 | ribeira grande
# Processing Record 76 of Set 2 | te anau
# Processing Record 77 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 78 of Set 2 | komsomolskiy
# Processing Record 79 of Set 2 | aporawan
# City not found. Skipping...
# Processing Record 80 of Set 2 | clyde river
# Processing Record 81 of Set 2 | lagoa
# Processing Record 82 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 83 of Set 2 | okha
# Processing Record 84 of Set 2 | talnakh
# Processing Record 85 of Set 2 | mgachi
# Processing Record 86 of Set 2 | port elizabeth
# Processing Record 87 of Set 2 | naze
# Processing Record 88 of Set 2 | puerto ayora
# Processing Record 89 of Set 2 | hermanus
# Processing Record 90 of Set 2 | tuatapere
# Processing Record 91 of Set 2 | iquique
# Processing Record 92 of Set 2 | hithadhoo
# Processing Record 93 of Set 2 | beringovskiy
# Processing Record 94 of Set 2 | jamestown
# Processing Record 95 of Set 2 | arraial do cabo
# Processing Record 96 of Set 2 | rawson
# Processing Record 97 of Set 2 | nichinan
# Processing Record 98 of Set 2 | tasiilaq
# Processing Record 99 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 100 of Set 2 | saint-joseph
# Processing Record 101 of Set 2 | salalah
# Processing Record 103 of Set 3 | cortes
# Processing Record 104 of Set 3 | niigata
# Processing Record 105 of Set 3 | codrington
# Processing Record 106 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 107 of Set 3 | urbandale
# Processing Record 108 of Set 3 | coquimbo
# Processing Record 109 of Set 3 | nuuk
# Processing Record 110 of Set 3 | muritiba
# Processing Record 111 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 112 of Set 3 | port lincoln
# Processing Record 113 of Set 3 | kysyl-syr
# Processing Record 114 of Set 3 | dingle
# Processing Record 115 of Set 3 | victoria
# Processing Record 116 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 117 of Set 3 | godda
# Processing Record 118 of Set 3 | sakakah
# Processing Record 119 of Set 3 | seymchan
# Processing Record 120 of Set 3 | suao
# City not found. Skipping...
# Processing Record 121 of Set 3 | kokopo
# Processing Record 122 of Set 3 | champasak
# Processing Record 123 of Set 3 | montepuez
# Processing Record 124 of Set 3 | atuona
# Processing Record 125 of Set 3 | marsh harbour
# Processing Record 126 of Set 3 | airai
# Processing Record 127 of Set 3 | provideniya
# Processing Record 128 of Set 3 | asyut
# Processing Record 129 of Set 3 | lakes entrance
# Processing Record 130 of Set 3 | bonavista
# Processing Record 131 of Set 3 | kaura namoda
# Processing Record 132 of Set 3 | gat
# Processing Record 133 of Set 3 | castro
# Processing Record 134 of Set 3 | jiblah
# Processing Record 135 of Set 3 | misratah
# Processing Record 136 of Set 3 | hobart
# Processing Record 137 of Set 3 | havre-saint-pierre
# Processing Record 138 of Set 3 | brae
# Processing Record 139 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 140 of Set 3 | manggar
# Processing Record 141 of Set 3 | vestmanna
# Processing Record 142 of Set 3 | laguna
# Processing Record 143 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 144 of Set 3 | sangar
# Processing Record 145 of Set 3 | manokwari
# Processing Record 146 of Set 3 | kushima
# Processing Record 147 of Set 3 | upernavik
# Processing Record 148 of Set 3 | cidreira
# Processing Record 149 of Set 3 | aquiraz
# Processing Record 150 of Set 3 | lompoc
# Processing Record 151 of Set 3 | atar
# Processing Record 152 of Set 3 | coahuayana
# Processing Record 154 of Set 4 | narsaq
# Processing Record 155 of Set 4 | kailua
# Processing Record 156 of Set 4 | itoman
# Processing Record 157 of Set 4 | mar del plata
# Processing Record 158 of Set 4 | bethanien
# Processing Record 159 of Set 4 | krasnoselkup
# Processing Record 160 of Set 4 | touros
# Processing Record 161 of Set 4 | east london
# Processing Record 162 of Set 4 | tawang
# Processing Record 163 of Set 4 | punta arenas
# Processing Record 164 of Set 4 | sao filipe
# Processing Record 165 of Set 4 | bintulu
# Processing Record 166 of Set 4 | wamba
# Processing Record 167 of Set 4 | ranfurly
# Processing Record 168 of Set 4 | saryg-sep
# Processing Record 169 of Set 4 | pionerskiy
# Processing Record 170 of Set 4 | quatre cocos
# Processing Record 171 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 172 of Set 4 | ribeira brava
# Processing Record 173 of Set 4 | porto novo
# Processing Record 174 of Set 4 | padang
# Processing Record 175 of Set 4 | pangnirtung
# Processing Record 176 of Set 4 | lavrentiya
# Processing Record 177 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 178 of Set 4 | chany
# Processing Record 179 of Set 4 | safaga
# Processing Record 180 of Set 4 | gorin
# Processing Record 181 of Set 4 | marawi
# Processing Record 182 of Set 4 | awbari
# Processing Record 183 of Set 4 | qiongshan
# Processing Record 184 of Set 4 | kamsack
# Processing Record 185 of Set 4 | lichinga
# Processing Record 186 of Set 4 | sitka
# Processing Record 187 of Set 4 | nelson bay
# Processing Record 188 of Set 4 | mayo
# Processing Record 189 of Set 4 | tikrit
# Processing Record 190 of Set 4 | saskylakh
# Processing Record 191 of Set 4 | meulaboh
# Processing Record 192 of Set 4 | weligama
# Processing Record 193 of Set 4 | payo
# Processing Record 194 of Set 4 | torbay
# Processing Record 195 of Set 4 | tiksi
# Processing Record 196 of Set 4 | maldonado
# Processing Record 197 of Set 4 | jardim
# Processing Record 198 of Set 4 | newala
# Processing Record 199 of Set 4 | necocli
# Processing Record 200 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 201 of Set 4 | karagaylinskiy
# Processing Record 202 of Set 4 | puerto carreno
# Processing Record 203 of Set 4 | carnarvon
# Processing Record 205 of Set 5 | flinders
# Processing Record 206 of Set 5 | erdaojiang
# Processing Record 207 of Set 5 | road town
# Processing Record 208 of Set 5 | kulhudhuffushi
# Processing Record 209 of Set 5 | pangody
# Processing Record 210 of Set 5 | vanavara
# Processing Record 211 of Set 5 | bilibino
# Processing Record 212 of Set 5 | georgetown
# Processing Record 213 of Set 5 | totness
# Processing Record 214 of Set 5 | rio de janeiro
# Processing Record 215 of Set 5 | ganzhou
# Processing Record 216 of Set 5 | salinopolis
# Processing Record 217 of Set 5 | northam
# Processing Record 218 of Set 5 | butaritari
# Processing Record 219 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 220 of Set 5 | coihaique
# Processing Record 221 of Set 5 | san andres
# Processing Record 222 of Set 5 | pevek
# Processing Record 223 of Set 5 | ilulissat
# Processing Record 224 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 225 of Set 5 | mercedes
# Processing Record 226 of Set 5 | illapel
# Processing Record 227 of Set 5 | comodoro rivadavia
# Processing Record 228 of Set 5 | luderitz
# Processing Record 229 of Set 5 | cururupu
# Processing Record 230 of Set 5 | channel-port aux basques
# Processing Record 231 of Set 5 | yaguajay
# Processing Record 232 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 233 of Set 5 | mayumba
# Processing Record 234 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 235 of Set 5 | ancud
# Processing Record 236 of Set 5 | lorengau
# Processing Record 237 of Set 5 | adrar
# Processing Record 238 of Set 5 | brunico
# Processing Record 239 of Set 5 | mocuba
# Processing Record 240 of Set 5 | mahibadhoo
# Processing Record 241 of Set 5 | tucurui
# Processing Record 242 of Set 5 | goderich
# Processing Record 243 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 244 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 245 of Set 5 | ashqelon
# Processing Record 246 of Set 5 | katsuura
# Processing Record 247 of Set 5 | el badari
# City not found. Skipping...
# Processing Record 248 of Set 5 | hamina
# Processing Record 249 of Set 5 | ferme-neuve
# Processing Record 250 of Set 5 | souillac
# Processing Record 251 of Set 5 | necochea
# Processing Record 252 of Set 5 | deer lake
# Processing Record 253 of Set 5 | aklavik
# Processing Record 254 of Set 5 | san cristobal
# Processing Record 256 of Set 6 | guerrero negro
# Processing Record 257 of Set 6 | seddon
# Processing Record 258 of Set 6 | omsukchan
# Processing Record 259 of Set 6 | saint-augustin
# Processing Record 260 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 261 of Set 6 | tessalit
# Processing Record 262 of Set 6 | kirchheim
# Processing Record 263 of Set 6 | esperantinopolis
# Processing Record 264 of Set 6 | strai
# Processing Record 265 of Set 6 | cabedelo
# Processing Record 266 of Set 6 | paita
# Processing Record 267 of Set 6 | sorland
# Processing Record 268 of Set 6 | chauk
# Processing Record 269 of Set 6 | poum
# Processing Record 270 of Set 6 | anchorage
# Processing Record 271 of Set 6 | ukiah
# Processing Record 272 of Set 6 | vao
# Processing Record 273 of Set 6 | nhulunbuy
# Processing Record 274 of Set 6 | kenai
# Processing Record 275 of Set 6 | stornoway
# Processing Record 276 of Set 6 | bonthe
# Processing Record 277 of Set 6 | semirom
# Processing Record 278 of Set 6 | ziarat
# Processing Record 279 of Set 6 | mackay
# Processing Record 280 of Set 6 | haines junction
# Processing Record 281 of Set 6 | rodrigues alves
# Processing Record 282 of Set 6 | hoima
# Processing Record 283 of Set 6 | bredy
# Processing Record 284 of Set 6 | thaton
# Processing Record 285 of Set 6 | kone
# Processing Record 286 of Set 6 | tutoia
# Processing Record 287 of Set 6 | amapa
# Processing Record 288 of Set 6 | roebourne
# Processing Record 289 of Set 6 | medina del campo
# Processing Record 290 of Set 6 | fairbanks
# Processing Record 291 of Set 6 | gao
# Processing Record 292 of Set 6 | ostrovnoy
# Processing Record 293 of Set 6 | pisco
# Processing Record 294 of Set 6 | shu
# Processing Record 295 of Set 6 | shelburne
# Processing Record 296 of Set 6 | kavaratti
# Processing Record 297 of Set 6 | saint-paul
# Processing Record 298 of Set 6 | etchoropo
# Processing Record 299 of Set 6 | jiaocheng
# Processing Record 300 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 301 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 302 of Set 6 | kargasok
# Processing Record 303 of Set 6 | savannah bight
# Processing Record 304 of Set 6 | altay
# Processing Record 305 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 307 of Set 7 | portree
# Processing Record 308 of Set 7 | kayerkan
# Processing Record 309 of Set 7 | ponta delgada
# Processing Record 310 of Set 7 | inongo
# Processing Record 311 of Set 7 | carutapera
# Processing Record 312 of Set 7 | orsha
# Processing Record 313 of Set 7 | recea
# Processing Record 314 of Set 7 | valdivia
# Processing Record 315 of Set 7 | nedryhayliv
# Processing Record 316 of Set 7 | tilichiki
# Processing Record 317 of Set 7 | riyadh
# Processing Record 318 of Set 7 | leeton
# Processing Record 319 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 320 of Set 7 | kermen
# Processing Record 321 of Set 7 | khandagayty
# Processing Record 322 of Set 7 | faya
# Processing Record 323 of Set 7 | vaitape
# Processing Record 324 of Set 7 | olafsvik
# Processing Record 325 of Set 7 | raga
# Processing Record 326 of Set 7 | nipawin
# Processing Record 327 of Set 7 | antofagasta
# Processing Record 328 of Set 7 | kaeo
# Processing Record 329 of Set 7 | nizhnyaya salda
# Processing Record 330 of Set 7 | oreanda
# City not found. Skipping...
# Processing Record 331 of Set 7 | buta
# Processing Record 332 of Set 7 | baturaja
# Processing Record 333 of Set 7 | parana
# Processing Record 334 of Set 7 | the valley
# Processing Record 335 of Set 7 | hasaki
# Processing Record 336 of Set 7 | cherskiy
# Processing Record 337 of Set 7 | ixtapa
# Processing Record 338 of Set 7 | chernyshevskiy
# Processing Record 339 of Set 7 | tautira
# Processing Record 340 of Set 7 | varadero
# Processing Record 341 of Set 7 | nishihara
# Processing Record 342 of Set 7 | zlitan
# Processing Record 343 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 344 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 345 of Set 7 | namibe
# Processing Record 346 of Set 7 | vrangel
# Processing Record 347 of Set 7 | weston-super-mare
# Processing Record 348 of Set 7 | bilma
# Processing Record 349 of Set 7 | cayenne
# Processing Record 350 of Set 7 | sakaiminato
# Processing Record 351 of Set 7 | tromso
# Processing Record 352 of Set 7 | krasnoye
# Processing Record 353 of Set 7 | ust-maya
# Processing Record 354 of Set 7 | lasa
# Processing Record 355 of Set 7 | tomatlan
# Processing Record 356 of Set 7 | sayyan
# Processing Record 358 of Set 8 | barstow
# Processing Record 359 of Set 8 | osmena
# Processing Record 360 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 361 of Set 8 | miri
# Processing Record 362 of Set 8 | katherine
# Processing Record 363 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 364 of Set 8 | prado
# Processing Record 365 of Set 8 | beloha
# Processing Record 366 of Set 8 | new norfolk
# Processing Record 367 of Set 8 | nyurba
# Processing Record 368 of Set 8 | rio gallegos
# Processing Record 369 of Set 8 | pitea
# Processing Record 370 of Set 8 | wahiawa
# Processing Record 371 of Set 8 | mtwara
# Processing Record 372 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 373 of Set 8 | thinadhoo
# Processing Record 374 of Set 8 | constitucion
# Processing Record 375 of Set 8 | makakilo city
# Processing Record 376 of Set 8 | angangxi
# City not found. Skipping...
# Processing Record 377 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 378 of Set 8 | kuala terengganu
# Processing Record 379 of Set 8 | palmares do sul
# Processing Record 380 of Set 8 | kavieng
# Processing Record 381 of Set 8 | half moon bay
# Processing Record 382 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 383 of Set 8 | karasjok
# Processing Record 384 of Set 8 | bokhan
# Processing Record 385 of Set 8 | kapit
# Processing Record 386 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 387 of Set 8 | istria
# Processing Record 388 of Set 8 | rjukan
# Processing Record 389 of Set 8 | hofn
# Processing Record 390 of Set 8 | marquette
# Processing Record 391 of Set 8 | labuhan
# Processing Record 392 of Set 8 | saveh
# Processing Record 393 of Set 8 | tshikapa
# Processing Record 394 of Set 8 | loukhi
# Processing Record 395 of Set 8 | terney
# Processing Record 396 of Set 8 | gondanglegi
# Processing Record 397 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 398 of Set 8 | bozoum
# Processing Record 399 of Set 8 | berlevag
# Processing Record 400 of Set 8 | thibodaux
# Processing Record 401 of Set 8 | hasanabad
# Processing Record 402 of Set 8 | donji komren
# City not found. Skipping...
# Processing Record 403 of Set 8 | lac-megantic
# Processing Record 404 of Set 8 | gotsu
# Processing Record 405 of Set 8 | iwaki
# Processing Record 406 of Set 8 | vanimo
# Processing Record 407 of Set 8 | alamosa
# Processing Record 409 of Set 9 | westport
# Processing Record 410 of Set 9 | uruzgan
# Processing Record 411 of Set 9 | san rafael del sur
# Processing Record 412 of Set 9 | alice
# Processing Record 413 of Set 9 | stephenville crossing
# Processing Record 414 of Set 9 | alenquer
# Processing Record 415 of Set 9 | jutai
# Processing Record 416 of Set 9 | caxito
# Processing Record 417 of Set 9 | rudnogorsk
# Processing Record 418 of Set 9 | rolla
# Processing Record 419 of Set 9 | nueva guinea
# Processing Record 420 of Set 9 | copiapo
# Processing Record 421 of Set 9 | santiago
# Processing Record 422 of Set 9 | elat
# Processing Record 423 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 424 of Set 9 | ozerna
# Processing Record 425 of Set 9 | hirara
# Processing Record 426 of Set 9 | aioi
# Processing Record 427 of Set 9 | roma
# Processing Record 428 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 429 of Set 9 | san luis
# Processing Record 430 of Set 9 | zhigansk
# Processing Record 431 of Set 9 | alliance
# Processing Record 432 of Set 9 | celestun
# Processing Record 433 of Set 9 | pulandian
# Processing Record 434 of Set 9 | mareeba
# Processing Record 435 of Set 9 | okhotsk
# Processing Record 436 of Set 9 | leningradskiy
# Processing Record 437 of Set 9 | buraydah
# Processing Record 438 of Set 9 | juba
# Processing Record 439 of Set 9 | cap-aux-meules
# Processing Record 440 of Set 9 | oktyabrskiy
# Processing Record 441 of Set 9 | aykhal
# Processing Record 442 of Set 9 | tonantins
# Processing Record 443 of Set 9 | zaysan
# Processing Record 444 of Set 9 | rucheng
# Processing Record 445 of Set 9 | acapulco
# Processing Record 446 of Set 9 | yumen
# Processing Record 447 of Set 9 | usinsk
# Processing Record 448 of Set 9 | novikovo
# Processing Record 449 of Set 9 | camacha
# Processing Record 450 of Set 9 | kahului
# Processing Record 451 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 452 of Set 9 | sioux lookout
# Processing Record 453 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 454 of Set 9 | turhal
# Processing Record 455 of Set 9 | khutar
# Processing Record 456 of Set 9 | antalaha
# Processing Record 457 of Set 9 | batagay
# Processing Record 458 of Set 9 | barbosa ferraz
# Processing Record 460 of Set 10 | orlik
# Processing Record 461 of Set 10 | leiyang
# Processing Record 462 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 463 of Set 10 | san juan
# Processing Record 464 of Set 10 | maniitsoq
# Processing Record 465 of Set 10 | koumac
# Processing Record 466 of Set 10 | iqaluit
# Processing Record 467 of Set 10 | santa cruz del sur
# Processing Record 468 of Set 10 | tokmak
# Processing Record 469 of Set 10 | biak
# Processing Record 470 of Set 10 | shieli
# Processing Record 471 of Set 10 | ayia marina
# Processing Record 472 of Set 10 | nalut
# Processing Record 473 of Set 10 | mongu
# Processing Record 474 of Set 10 | nanortalik
# Processing Record 475 of Set 10 | larsnes
# Processing Record 476 of Set 10 | rio grande
# Processing Record 477 of Set 10 | trairi
# Processing Record 478 of Set 10 | high level
# Processing Record 479 of Set 10 | san quintin
# Processing Record 480 of Set 10 | warrington
# Processing Record 481 of Set 10 | leshan
# Processing Record 482 of Set 10 | businga
# Processing Record 483 of Set 10 | tokamachi
# Processing Record 484 of Set 10 | almonte
# Processing Record 485 of Set 10 | sorong
# Processing Record 486 of Set 10 | mount gambier
# Processing Record 487 of Set 10 | vardo
# Processing Record 488 of Set 10 | baykit
# Processing Record 489 of Set 10 | namtsy
# Processing Record 490 of Set 10 | broome
# Processing Record 491 of Set 10 | north bend
# Processing Record 492 of Set 10 | ahar
# Processing Record 493 of Set 10 | tarauaca
# Processing Record 494 of Set 10 | verkhniye sergi
# Processing Record 495 of Set 10 | gizo
# Processing Record 496 of Set 10 | iwanai
# Processing Record 497 of Set 10 | chegdomyn
# Processing Record 498 of Set 10 | qaqortoq
# Processing Record 499 of Set 10 | mayya
# Processing Record 500 of Set 10 | pingzhuang
# Processing Record 501 of Set 10 | barranca
# Processing Record 502 of Set 10 | general pico
# Processing Record 503 of Set 10 | sao joao da barra
# Processing Record 504 of Set 10 | homer
# Processing Record 505 of Set 10 | bathsheba
# Processing Record 506 of Set 10 | lykhivka
# Processing Record 507 of Set 10 | marzuq
# Processing Record 508 of Set 10 | sennoy
# Processing Record 509 of Set 10 | colomi
# Processing Record 511 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 512 of Set 11 | kamloops
# Processing Record 513 of Set 11 | oriximina
# Processing Record 514 of Set 11 | viedma
# Processing Record 515 of Set 11 | hukuntsi
# Processing Record 516 of Set 11 | barra patuca
# Processing Record 517 of Set 11 | dillon
# Processing Record 518 of Set 11 | susehri
# Processing Record 519 of Set 11 | praia
# Processing Record 520 of Set 11 | nemencine
# Processing Record 521 of Set 11 | vila franca do campo
# Processing Record 522 of Set 11 | naica
# Processing Record 523 of Set 11 | buala
# Processing Record 524 of Set 11 | centralia
# Processing Record 525 of Set 11 | nome
# Processing Record 526 of Set 11 | livingston
# Processing Record 527 of Set 11 | flin flon
# Processing Record 528 of Set 11 | pozo colorado
# Processing Record 529 of Set 11 | kloulklubed
# Processing Record 530 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 531 of Set 11 | hobyo
# Processing Record 532 of Set 11 | ribnica
# Processing Record 533 of Set 11 | chicama
# Processing Record 534 of Set 11 | mogadishu
# Processing Record 535 of Set 11 | ramshir
# Processing Record 536 of Set 11 | marovoay
# Processing Record 537 of Set 11 | geraldton
# Processing Record 538 of Set 11 | tazovskiy
# Processing Record 539 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 540 of Set 11 | conde
# Processing Record 541 of Set 11 | quchan
# Processing Record 542 of Set 11 | dhana
# Processing Record 543 of Set 11 | havoysund
# Processing Record 544 of Set 11 | magalia
# Processing Record 545 of Set 11 | kruisfontein
# Processing Record 546 of Set 11 | ahipara
# Processing Record 547 of Set 11 | dingzhou
# Processing Record 548 of Set 11 | along
# Processing Record 549 of Set 11 | berea
# Processing Record 550 of Set 11 | denpasar
# Processing Record 551 of Set 11 | yurla
# Processing Record 552 of Set 11 | epe
# Processing Record 553 of Set 11 | lokoja
# Processing Record 554 of Set 11 | meadow lake
# Processing Record 555 of Set 11 | raudeberg
# Processing Record 556 of Set 11 | tigzirt
# Processing Record 557 of Set 11 | fare
# Processing Record 558 of Set 11 | avera
# Processing Record 559 of Set 11 | beyneu
# Processing Record 560 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 562 of Set 12 | mount isa
# Processing Record 563 of Set 12 | onega
# Processing Record 564 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 565 of Set 12 | bardiyah
# Processing Record 566 of Set 12 | klaksvik
# Processing Record 567 of Set 12 | gawan
# Processing Record 568 of Set 12 | san pedro
# Processing Record 569 of Set 12 | igarka
# Processing Record 570 of Set 12 | banda aceh
# Processing Record 571 of Set 12 | omutinskoye
# City not found. Skipping...
# Processing Record 572 of Set 12 | zapolyarnyy
# Processing Record 573 of Set 12 | muzhi
# Processing Record 574 of Set 12 | mabaruma
# Processing Record 575 of Set 12 | araucaria
# Processing Record 576 of Set 12 | axim
# Processing Record 577 of Set 12 | dudinka
# Processing Record 578 of Set 12 | esso
# Processing Record 579 of Set 12 | lumphat
# Processing Record 580 of Set 12 | sandpoint
# Processing Record 581 of Set 12 | isla mujeres
# Processing Record 582 of Set 12 | tucuman
# Processing Record 583 of Set 12 | yeppoon
# Processing Record 584 of Set 12 | totma
# Processing Record 585 of Set 12 | ushtobe
# Processing Record 586 of Set 12 | tecoanapa
# Processing Record 587 of Set 12 | la roche-sur-yon
# Processing Record 588 of Set 12 | kijang
# Processing Record 589 of Set 12 | buchanan
# Processing Record 590 of Set 12 | kununurra
# Processing Record 591 of Set 12 | dwarka
# Processing Record 592 of Set 12 | honiara
# Processing Record 593 of Set 12 | timmins
# Processing Record 594 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 595 of Set 12 | batken
# Processing Record 596 of Set 12 | talaya
# Processing Record 597 of Set 12 | penzberg
# Processing Record 598 of Set 12 | cockburn town
# Processing Record 599 of Set 12 | conway
# Processing Record 600 of Set 12 | vilhena
# Processing Record 601 of Set 12 | rangkasbitung
# Processing Record 602 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 603 of Set 12 | la libertad
# Processing Record 604 of Set 12 | andenes
# Processing Record 605 of Set 12 | vysotsk
# Processing Record 606 of Set 12 | kuzovatovo
# Processing Record 607 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 608 of Set 12 | grand forks
# Processing Record 609 of Set 12 | taoudenni
# Processing Record 610 of Set 12 | saint-francois
# Processing Record 611 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 613 of Set 13 | olinda
# Processing Record 614 of Set 13 | douglas
# Processing Record 615 of Set 13 | stephenville
# Processing Record 616 of Set 13 | karratha
# Processing Record 617 of Set 13 | markova
# Processing Record 618 of Set 13 | kutum
# Processing Record 619 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 620 of Set 13 | le port
# Processing Record 621 of Set 13 | bandipur
# Processing Record 622 of Set 13 | tahe
# Processing Record 623 of Set 13 | yar-sale
# Processing Record 624 of Set 13 | zyryanka
# Processing Record 625 of Set 13 | moron
# Processing Record 626 of Set 13 | caravelas
# Processing Record 627 of Set 13 | egvekinot
# Processing Record 628 of Set 13 | slave lake
# Processing Record 629 of Set 13 | inhambane
# Processing Record 630 of Set 13 | litovko
# Processing Record 631 of Set 13 | meiganga
# Processing Record 632 of Set 13 | bundaberg
# Processing Record 633 of Set 13 | galle
# Processing Record 634 of Set 13 | suez
# Processing Record 635 of Set 13 | ugoofaaru
# Processing Record 636 of Set 13 | de aar
# Processing Record 637 of Set 13 | zherdevka
# Processing Record 638 of Set 13 | veinticinco de mayo
# Processing Record 639 of Set 13 | gostyn
# Processing Record 640 of Set 13 | ayan
# Processing Record 641 of Set 13 | khanewal
# Processing Record 642 of Set 13 | marang
# Processing Record 643 of Set 13 | kabo
# Processing Record 644 of Set 13 | paramonga
# Processing Record 645 of Set 13 | san vicente
# Processing Record 646 of Set 13 | kudahuvadhoo
# Processing Record 647 of Set 13 | la ronge
# Processing Record 648 of Set 13 | cabo san lucas
# Processing Record 649 of Set 13 | whitehorse
# Processing Record 650 of Set 13 | vieux-habitants
# Processing Record 651 of Set 13 | lagos
# Processing Record 652 of Set 13 | duz
# City not found. Skipping...
# Processing Record 653 of Set 13 | dunedin
# Processing Record 654 of Set 13 | koygorodok
# Processing Record 655 of Set 13 | agadez
# Processing Record 656 of Set 13 | langsa
# Processing Record 657 of Set 13 | arman
# Processing Record 658 of Set 13 | koubia
# Processing Record 659 of Set 13 | esil
# Processing Record 660 of Set 13 | aksu
# Processing Record 661 of Set 13 | najran
# Processing Record 662 of Set 13 | orzhytsya
# Processing Record 664 of Set 14 | tacoronte
# Processing Record 665 of Set 14 | pacific grove
# Processing Record 666 of Set 14 | kaeng khoi
# Processing Record 667 of Set 14 | yulara
# Processing Record 668 of Set 14 | moranbah
# Processing Record 669 of Set 14 | vestmannaeyjar
# Processing Record 670 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 671 of Set 14 | yatou
# Processing Record 672 of Set 14 | zhenhai
# Processing Record 673 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 674 of Set 14 | chinsali
# Processing Record 675 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 676 of Set 14 | korla
# Processing Record 677 of Set 14 | kholmogory
# Processing Record 678 of Set 14 | billings
# Processing Record 679 of Set 14 | auki
# Processing Record 680 of Set 14 | ucluelet
# Processing Record 681 of Set 14 | novo selo
# Processing Record 682 of Set 14 | singaraja
# Processing Record 683 of Set 14 | mangualde
# Processing Record 684 of Set 14 | namatanai
# Processing Record 685 of Set 14 | karacakoy
# Processing Record 686 of Set 14 | portland
# Processing Record 687 of Set 14 | puerto maldonado
# Processing Record 688 of Set 14 | amberley
# Processing Record 689 of Set 14 | mnogovershinnyy
# Processing Record 690 of Set 14 | hualmay
# Processing Record 691 of Set 14 | belyy yar
# Processing Record 692 of Set 14 | palmer
# Processing Record 693 of Set 14 | mpongwe
# Processing Record 694 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 695 of Set 14 | houston
# Processing Record 696 of Set 14 | syamzha
# Processing Record 697 of Set 14 | waingapu
# Processing Record 698 of Set 14 | mazamari
# Processing Record 699 of Set 14 | khandyga
# Processing Record 700 of Set 14 | moquegua
# Processing Record 701 of Set 14 | omboue
# Processing Record 702 of Set 14 | humaita
# Processing Record 703 of Set 14 | yinchuan
# Processing Record 704 of Set 14 | lakatoro
# Processing Record 705 of Set 14 | ca mau
# Processing Record 706 of Set 14 | shihezi
# Processing Record 707 of Set 14 | orebro
# Processing Record 708 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 709 of Set 14 | belaya gora
# Processing Record 710 of Set 14 | ozieri
# Processing Record 711 of Set 14 | luocheng
# Processing Record 712 of Set 14 | ishigaki
# Processing Record 713 of Set 14 | whitecourt
# Processing Record 715 of Set 15 | amargosa
# Processing Record 716 of Set 15 | pavlogradka
# Processing Record 717 of Set 15 | bam
# Processing Record 718 of Set 15 | isangel
# Processing Record 719 of Set 15 | progreso
# Processing Record 720 of Set 15 | curup
# Processing Record 721 of Set 15 | jinxiang
# Processing Record 722 of Set 15 | ako
# Processing Record 723 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 724 of Set 15 | port augusta
# Processing Record 725 of Set 15 | soyo
# Processing Record 726 of Set 15 | huaicheng
# Processing Record 727 of Set 15 | panama city
# Processing Record 728 of Set 15 | duldurga
# Processing Record 729 of Set 15 | vila velha
# Processing Record 730 of Set 15 | numaligarh
# Processing Record 731 of Set 15 | aden
# Processing Record 732 of Set 15 | frontera
# Processing Record 733 of Set 15 | cuiluan
# Processing Record 734 of Set 15 | bukachacha
# Processing Record 735 of Set 15 | grindavik
# Processing Record 736 of Set 15 | lukovetskiy
# Processing Record 737 of Set 15 | fort nelson
# Processing Record 738 of Set 15 | rathdrum
# Processing Record 739 of Set 15 | margate
# Processing Record 740 of Set 15 | mehamn
# Processing Record 741 of Set 15 | aswan
# Processing Record 742 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 743 of Set 15 | kungurtug
# Processing Record 744 of Set 15 | jiwani
# Processing Record 745 of Set 15 | spokane
# Processing Record 746 of Set 15 | tommot
# Processing Record 747 of Set 15 | mezen
# Processing Record 748 of Set 15 | punta alta
# Processing Record 749 of Set 15 | songkhla
# Processing Record 750 of Set 15 | burnie
# Processing Record 751 of Set 15 | ust-kuyga
# Processing Record 752 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 753 of Set 15 | linxia
# Processing Record 754 of Set 15 | semey
# Processing Record 755 of Set 15 | monte patria
# Processing Record 756 of Set 15 | pierre
# Processing Record 757 of Set 15 | ignatovka
# Processing Record 758 of Set 15 | australind
# Processing Record 759 of Set 15 | truth or consequences
# Processing Record 760 of Set 15 | mana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Nemuro      JP  43.3236  145.5750     32.07        92         100
# 1        Dikson      RU  73.5069   80.5464      6.67        87         100
# 2        Viesca      MX  25.3500 -102.8000     68.00        56           1
# 3  San Patricio      US  28.0170  -97.5169     72.00        78          90
# 4     Esperance      AU -33.8667  121.9000     62.60        88           7
# 5      Khatanga      RU  71.9667  102.5000    -16.20        91          11
# 6       Husavik      IS  66.0449  -17.3389     14.00        92          90
# 7       Qaanaaq      GL  77.4840  -69.3632    -12.93        67          15
# 8        Avarua      CK -21.2078 -159.7750     80.60        83          75
# 9       Ushuaia      AR -54.8000  -68.3000     42.80        75          20
#
#    Wind Speed      Description
# 0       14.83             snow
# 1        7.90  overcast clouds
# 2        3.58        clear sky
# 3        8.05  overcast clouds
# 4       14.97        clear sky
# 5        6.06       few clouds
# 6       28.77             snow
# 7        6.80       few clouds
# 8       12.66    broken clouds
# 9        6.91       few clouds

# %%
# Export the dataframe to a csv file.
output_data_file = "WeatherPy_database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
