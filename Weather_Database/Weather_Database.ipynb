# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import requests
from citipy import citipy
import json

# %%
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kondinskoye
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | sitka
# Processing Record 4 of Set 1 | kot diji
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | maragogi
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | mandalgovi
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | alvorada
# Processing Record 21 of Set 1 | talnakh
# Processing Record 22 of Set 1 | mbandaka
# Processing Record 23 of Set 1 | gorom-gorom
# Processing Record 24 of Set 1 | offa
# Processing Record 25 of Set 1 | balad
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | vicuna
# Processing Record 28 of Set 1 | torun
# Processing Record 29 of Set 1 | anloga
# Processing Record 30 of Set 1 | aklavik
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | naze
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | hambantota
# Processing Record 35 of Set 1 | gola gokarannath
# Processing Record 36 of Set 1 | owase
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | mehamn
# Processing Record 39 of Set 1 | alihe
# Processing Record 40 of Set 1 | khash
# Processing Record 41 of Set 1 | beloha
# Processing Record 42 of Set 1 | erzin
# Processing Record 43 of Set 1 | victoria
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | vila velha
# Processing Record 46 of Set 1 | forest grove
# Processing Record 47 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 1 | saint-georges
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | hermanus
# Processing Record 52 of Set 2 | barnstaple
# Processing Record 53 of Set 2 | portland
# Processing Record 54 of Set 2 | foix
# Processing Record 55 of Set 2 | atuona
# Processing Record 56 of Set 2 | elizabeth city
# Processing Record 57 of Set 2 | ushuaia
# Processing Record 58 of Set 2 | pevek
# Processing Record 59 of Set 2 | barrow
# Processing Record 60 of Set 2 | saint-francois
# Processing Record 61 of Set 2 | te karaka
# Processing Record 62 of Set 2 | ekangala
# Processing Record 63 of Set 2 | molos
# Processing Record 64 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 65 of Set 2 | cidreira
# Processing Record 66 of Set 2 | tasiilaq
# Processing Record 67 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 68 of Set 2 | kaitangata
# Processing Record 69 of Set 2 | chuy
# Processing Record 70 of Set 2 | yellowknife
# Processing Record 71 of Set 2 | sangar
# Processing Record 72 of Set 2 | hilo
# Processing Record 73 of Set 2 | cloquet
# Processing Record 74 of Set 2 | san-pedro
# Processing Record 75 of Set 2 | thompson
# Processing Record 76 of Set 2 | lavumisa
# Processing Record 77 of Set 2 | lavrentiya
# Processing Record 78 of Set 2 | ust-barguzin
# Processing Record 79 of Set 2 | mahebourg
# Processing Record 80 of Set 2 | georgetown
# Processing Record 81 of Set 2 | aksarka
# Processing Record 82 of Set 2 | bluff
# Processing Record 83 of Set 2 | hofn
# Processing Record 84 of Set 2 | cherskiy
# Processing Record 85 of Set 2 | macau
# Processing Record 86 of Set 2 | busselton
# Processing Record 87 of Set 2 | kawalu
# Processing Record 88 of Set 2 | dawson creek
# Processing Record 89 of Set 2 | alofi
# Processing Record 90 of Set 2 | chulman
# Processing Record 91 of Set 2 | castro
# Processing Record 92 of Set 2 | mogadishu
# Processing Record 93 of Set 2 | denia
# Processing Record 94 of Set 2 | saldanha
# Processing Record 95 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 96 of Set 2 | yazykovo
# Processing Record 97 of Set 2 | kasaoka
# Processing Record 98 of Set 2 | tevriz
# Processing Record 99 of Set 2 | mar del plata
# Processing Record 100 of Set 2 | buraydah
# Processing Record 101 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 103 of Set 3 | ribeira grande
# Processing Record 104 of Set 3 | jiwani
# Processing Record 105 of Set 3 | qaanaaq
# Processing Record 106 of Set 3 | iqaluit
# Processing Record 107 of Set 3 | upernavik
# Processing Record 108 of Set 3 | lorengau
# Processing Record 109 of Set 3 | mount isa
# Processing Record 110 of Set 3 | saint anthony
# Processing Record 111 of Set 3 | hithadhoo
# Processing Record 112 of Set 3 | mutis
# Processing Record 113 of Set 3 | hasaki
# Processing Record 114 of Set 3 | cape town
# Processing Record 115 of Set 3 | vung tau
# Processing Record 116 of Set 3 | sao felix do xingu
# Processing Record 117 of Set 3 | yoichi
# Processing Record 118 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 119 of Set 3 | graaff-reinet
# Processing Record 120 of Set 3 | camacha
# Processing Record 121 of Set 3 | egvekinot
# Processing Record 122 of Set 3 | cap malheureux
# Processing Record 123 of Set 3 | malanje
# Processing Record 124 of Set 3 | tuatapere
# Processing Record 125 of Set 3 | raga
# Processing Record 126 of Set 3 | rawson
# Processing Record 127 of Set 3 | bowen
# Processing Record 128 of Set 3 | kargasok
# Processing Record 129 of Set 3 | labelle
# Processing Record 130 of Set 3 | pisco
# Processing Record 131 of Set 3 | teguise
# Processing Record 132 of Set 3 | vanimo
# Processing Record 133 of Set 3 | makat
# Processing Record 134 of Set 3 | karratha
# Processing Record 135 of Set 3 | longyearbyen
# Processing Record 136 of Set 3 | new norfolk
# Processing Record 137 of Set 3 | sarkand
# Processing Record 138 of Set 3 | mataura
# Processing Record 139 of Set 3 | srednekolymsk
# Processing Record 140 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 141 of Set 3 | bengkulu
# Processing Record 142 of Set 3 | san patricio
# Processing Record 143 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 144 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 145 of Set 3 | carnarvon
# Processing Record 146 of Set 3 | sao jose da coroa grande
# Processing Record 147 of Set 3 | vagur
# Processing Record 148 of Set 3 | blue springs
# Processing Record 149 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 150 of Set 3 | puerto colombia
# Processing Record 151 of Set 3 | severo-kurilsk
# Processing Record 152 of Set 3 | kruisfontein
# Processing Record 154 of Set 4 | mamit
# Processing Record 155 of Set 4 | wielun
# Processing Record 156 of Set 4 | baixa grande
# Processing Record 157 of Set 4 | kanashevo
# Processing Record 158 of Set 4 | mecca
# Processing Record 159 of Set 4 | makakilo city
# Processing Record 160 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 161 of Set 4 | lebu
# Processing Record 162 of Set 4 | danshui
# Processing Record 163 of Set 4 | mitsamiouli
# Processing Record 164 of Set 4 | luderitz
# Processing Record 165 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 166 of Set 4 | vestmanna
# Processing Record 167 of Set 4 | narsaq
# Processing Record 168 of Set 4 | russell
# Processing Record 169 of Set 4 | saint-philippe
# Processing Record 170 of Set 4 | kampot
# Processing Record 171 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 172 of Set 4 | saint george
# Processing Record 173 of Set 4 | bud
# Processing Record 174 of Set 4 | pucallpa
# Processing Record 175 of Set 4 | tiksi
# Processing Record 176 of Set 4 | eirunepe
# Processing Record 177 of Set 4 | bubaque
# Processing Record 178 of Set 4 | ronda
# Processing Record 179 of Set 4 | provideniya
# Processing Record 180 of Set 4 | reconquista
# Processing Record 181 of Set 4 | san quintin
# Processing Record 182 of Set 4 | broken hill
# Processing Record 183 of Set 4 | kisangani
# Processing Record 184 of Set 4 | sao filipe
# Processing Record 185 of Set 4 | dunedin
# Processing Record 186 of Set 4 | chateau-thierry
# Processing Record 187 of Set 4 | ilulissat
# Processing Record 188 of Set 4 | mounana
# Processing Record 189 of Set 4 | pangnirtung
# Processing Record 190 of Set 4 | cabo san lucas
# Processing Record 191 of Set 4 | nanortalik
# Processing Record 192 of Set 4 | avarua
# Processing Record 193 of Set 4 | sao miguel do araguaia
# Processing Record 194 of Set 4 | east london
# Processing Record 195 of Set 4 | faya
# Processing Record 196 of Set 4 | fortuna
# Processing Record 197 of Set 4 | norman wells
# Processing Record 198 of Set 4 | vardo
# Processing Record 199 of Set 4 | matara
# Processing Record 200 of Set 4 | tulnici
# Processing Record 201 of Set 4 | sibolga
# Processing Record 202 of Set 4 | tautira
# Processing Record 203 of Set 4 | billings
# Processing Record 205 of Set 5 | nouakchott
# Processing Record 206 of Set 5 | menomonie
# Processing Record 207 of Set 5 | pacific grove
# Processing Record 208 of Set 5 | tromso
# Processing Record 209 of Set 5 | oranjemund
# Processing Record 210 of Set 5 | campiglia marittima
# Processing Record 211 of Set 5 | ponta do sol
# Processing Record 212 of Set 5 | shingu
# Processing Record 213 of Set 5 | geraldton
# Processing Record 214 of Set 5 | rocha
# Processing Record 215 of Set 5 | luanda
# Processing Record 216 of Set 5 | tarko-sale
# Processing Record 217 of Set 5 | port-cartier
# Processing Record 218 of Set 5 | adrar
# Processing Record 219 of Set 5 | batagay-alyta
# Processing Record 220 of Set 5 | berlevag
# Processing Record 221 of Set 5 | lakshettipet
# Processing Record 222 of Set 5 | atar
# Processing Record 223 of Set 5 | borogontsy
# Processing Record 224 of Set 5 | kasongo-lunda
# Processing Record 225 of Set 5 | aswan
# Processing Record 226 of Set 5 | meulaboh
# Processing Record 227 of Set 5 | lieksa
# Processing Record 228 of Set 5 | chabahar
# Processing Record 229 of Set 5 | cedar city
# Processing Record 230 of Set 5 | galbshtadt
# Processing Record 231 of Set 5 | nishihara
# Processing Record 232 of Set 5 | kodiak
# Processing Record 233 of Set 5 | porto-vecchio
# Processing Record 234 of Set 5 | petropavlovskoye
# Processing Record 235 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 236 of Set 5 | amazar
# Processing Record 237 of Set 5 | atambua
# Processing Record 238 of Set 5 | consolacion del sur
# Processing Record 239 of Set 5 | nyurba
# Processing Record 240 of Set 5 | lagoa
# Processing Record 241 of Set 5 | general roca
# Processing Record 242 of Set 5 | charters towers
# Processing Record 243 of Set 5 | havre-saint-pierre
# Processing Record 244 of Set 5 | manggar
# Processing Record 245 of Set 5 | vasilyevskiy mokh
# Processing Record 246 of Set 5 | goderich
# Processing Record 247 of Set 5 | kupang
# Processing Record 248 of Set 5 | seguela
# Processing Record 249 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 250 of Set 5 | saskylakh
# Processing Record 251 of Set 5 | mildura
# Processing Record 252 of Set 5 | belem de sao francisco
# Processing Record 253 of Set 5 | channel-port aux basques
# Processing Record 254 of Set 5 | farafangana
# Processing Record 256 of Set 6 | zhigansk
# Processing Record 257 of Set 6 | zhenlai
# Processing Record 258 of Set 6 | yarada
# Processing Record 259 of Set 6 | nalut
# Processing Record 260 of Set 6 | puerto del rosario
# Processing Record 261 of Set 6 | novoomskiy
# Processing Record 262 of Set 6 | natchitoches
# Processing Record 263 of Set 6 | gouvieux
# Processing Record 264 of Set 6 | arinos
# Processing Record 265 of Set 6 | tura
# Processing Record 266 of Set 6 | khor
# Processing Record 267 of Set 6 | bathsheba
# Processing Record 268 of Set 6 | yulara
# Processing Record 269 of Set 6 | guerrero negro
# Processing Record 270 of Set 6 | mayumba
# Processing Record 271 of Set 6 | karacabey
# Processing Record 272 of Set 6 | bethel
# Processing Record 273 of Set 6 | jelling
# Processing Record 274 of Set 6 | nieuw amsterdam
# Processing Record 275 of Set 6 | dzaoudzi
# Processing Record 276 of Set 6 | maraa
# Processing Record 277 of Set 6 | santa maria
# Processing Record 278 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 279 of Set 6 | madang
# Processing Record 280 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 281 of Set 6 | sompeta
# Processing Record 282 of Set 6 | borba
# Processing Record 283 of Set 6 | college
# Processing Record 284 of Set 6 | vila franca do campo
# Processing Record 285 of Set 6 | laguna
# Processing Record 286 of Set 6 | henties bay
# Processing Record 287 of Set 6 | san cristobal
# Processing Record 288 of Set 6 | kavaratti
# Processing Record 289 of Set 6 | dikson
# Processing Record 290 of Set 6 | kahului
# Processing Record 291 of Set 6 | purranque
# Processing Record 292 of Set 6 | stromness
# Processing Record 293 of Set 6 | ust-kan
# Processing Record 294 of Set 6 | northam
# Processing Record 295 of Set 6 | mwense
# Processing Record 296 of Set 6 | borisoglebskiy
# Processing Record 297 of Set 6 | hendijan
# City not found. Skipping...
# Processing Record 298 of Set 6 | nola
# Processing Record 299 of Set 6 | azare
# Processing Record 300 of Set 6 | leningradskiy
# Processing Record 301 of Set 6 | najran
# Processing Record 302 of Set 6 | lianga
# Processing Record 303 of Set 6 | ahipara
# Processing Record 304 of Set 6 | holme
# Processing Record 305 of Set 6 | valle hermoso
# Processing Record 307 of Set 7 | beringovskiy
# Processing Record 308 of Set 7 | koundara
# Processing Record 309 of Set 7 | alghero
# Processing Record 310 of Set 7 | kavieng
# Processing Record 311 of Set 7 | necochea
# Processing Record 312 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 313 of Set 7 | wencheng
# Processing Record 314 of Set 7 | flinders
# Processing Record 315 of Set 7 | kindu
# Processing Record 316 of Set 7 | mudanjiang
# Processing Record 317 of Set 7 | arraial do cabo
# Processing Record 318 of Set 7 | hobyo
# Processing Record 319 of Set 7 | bayanday
# Processing Record 320 of Set 7 | huilong
# Processing Record 321 of Set 7 | andijon
# Processing Record 322 of Set 7 | pauini
# Processing Record 323 of Set 7 | domat
# Processing Record 324 of Set 7 | lloydminster
# Processing Record 325 of Set 7 | launceston
# Processing Record 326 of Set 7 | say
# Processing Record 327 of Set 7 | shebunino
# Processing Record 328 of Set 7 | bati
# Processing Record 329 of Set 7 | auki
# Processing Record 330 of Set 7 | waipawa
# Processing Record 331 of Set 7 | zhanaozen
# Processing Record 332 of Set 7 | juegang
# Processing Record 333 of Set 7 | saint-paul
# Processing Record 334 of Set 7 | torbay
# Processing Record 335 of Set 7 | arrifes
# Processing Record 336 of Set 7 | labuhan
# Processing Record 337 of Set 7 | srikakulam
# Processing Record 338 of Set 7 | wanaka
# Processing Record 339 of Set 7 | vincennes
# Processing Record 340 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 341 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 342 of Set 7 | nyaunglebin
# Processing Record 343 of Set 7 | salalah
# Processing Record 344 of Set 7 | rio grande
# Processing Record 345 of Set 7 | taoudenni
# Processing Record 346 of Set 7 | marsa matruh
# Processing Record 347 of Set 7 | yeppoon
# Processing Record 348 of Set 7 | doha
# Processing Record 349 of Set 7 | darhan
# Processing Record 350 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 351 of Set 7 | cuauhtemoc
# Processing Record 352 of Set 7 | ossora
# Processing Record 353 of Set 7 | sorland
# Processing Record 354 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 355 of Set 7 | paamiut
# Processing Record 356 of Set 7 | te anau
# Processing Record 358 of Set 8 | bandarbeyla
# Processing Record 359 of Set 8 | tilichiki
# Processing Record 360 of Set 8 | banjar
# Processing Record 361 of Set 8 | kiama
# Processing Record 362 of Set 8 | vao
# Processing Record 363 of Set 8 | shangrao
# Processing Record 364 of Set 8 | katsuura
# Processing Record 365 of Set 8 | cerquilho
# Processing Record 366 of Set 8 | cockburn town
# Processing Record 367 of Set 8 | altamont
# Processing Record 368 of Set 8 | sembe
# Processing Record 369 of Set 8 | deer lake
# Processing Record 370 of Set 8 | pierre
# Processing Record 371 of Set 8 | turukhansk
# Processing Record 372 of Set 8 | umm lajj
# Processing Record 373 of Set 8 | illapel
# Processing Record 374 of Set 8 | czersk
# Processing Record 375 of Set 8 | coari
# Processing Record 376 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 377 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 378 of Set 8 | mangrol
# Processing Record 379 of Set 8 | andenes
# Processing Record 380 of Set 8 | valdivia
# Processing Record 381 of Set 8 | santa cruz de la palma
# Processing Record 382 of Set 8 | neuquen
# Processing Record 383 of Set 8 | nelson bay
# Processing Record 384 of Set 8 | christchurch
# Processing Record 385 of Set 8 | turba
# Processing Record 386 of Set 8 | cabedelo
# Processing Record 387 of Set 8 | porto tolle
# Processing Record 388 of Set 8 | gidam
# Processing Record 389 of Set 8 | fairbanks
# Processing Record 390 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 391 of Set 8 | groton
# Processing Record 392 of Set 8 | madingou
# Processing Record 393 of Set 8 | butka
# Processing Record 394 of Set 8 | kidal
# Processing Record 395 of Set 8 | cayenne
# Processing Record 396 of Set 8 | tecoluca
# Processing Record 397 of Set 8 | caravelas
# Processing Record 398 of Set 8 | corinto
# Processing Record 399 of Set 8 | rumonge
# Processing Record 400 of Set 8 | ratnagiri
# Processing Record 401 of Set 8 | loa janan
# Processing Record 402 of Set 8 | suluq
# Processing Record 403 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 404 of Set 8 | kismayo
# Processing Record 405 of Set 8 | drakhtik
# Processing Record 406 of Set 8 | polillo
# Processing Record 407 of Set 8 | vanavara
# Processing Record 409 of Set 9 | samarai
# Processing Record 410 of Set 9 | aitape
# Processing Record 411 of Set 9 | namatanai
# Processing Record 412 of Set 9 | wattegama
# Processing Record 413 of Set 9 | louga
# Processing Record 414 of Set 9 | prince rupert
# Processing Record 415 of Set 9 | xichang
# Processing Record 416 of Set 9 | half moon bay
# Processing Record 417 of Set 9 | rathdrum
# Processing Record 418 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 419 of Set 9 | elmina
# Processing Record 420 of Set 9 | palimbang
# Processing Record 421 of Set 9 | lakatoro
# Processing Record 422 of Set 9 | lompoc
# Processing Record 423 of Set 9 | aiquile
# Processing Record 424 of Set 9 | aden
# Processing Record 425 of Set 9 | bushehr
# Processing Record 426 of Set 9 | port macquarie
# Processing Record 427 of Set 9 | boundiali
# Processing Record 428 of Set 9 | brae
# Processing Record 429 of Set 9 | sao borja
# Processing Record 430 of Set 9 | debre birhan
# Processing Record 431 of Set 9 | balkhash
# Processing Record 432 of Set 9 | qingdao
# Processing Record 433 of Set 9 | hit
# Processing Record 434 of Set 9 | uige
# Processing Record 435 of Set 9 | jawa
# Processing Record 436 of Set 9 | boca del monte
# Processing Record 437 of Set 9 | desnogorsk
# Processing Record 438 of Set 9 | severouralsk
# Processing Record 439 of Set 9 | lata
# Processing Record 440 of Set 9 | honningsvag
# Processing Record 441 of Set 9 | yarmouth
# Processing Record 442 of Set 9 | bonavista
# Processing Record 443 of Set 9 | ancud
# Processing Record 444 of Set 9 | klaksvik
# Processing Record 445 of Set 9 | tyup
# Processing Record 446 of Set 9 | guarda
# Processing Record 447 of Set 9 | teya
# Processing Record 448 of Set 9 | hovd
# Processing Record 449 of Set 9 | kintampo
# Processing Record 450 of Set 9 | tagusao
# Processing Record 451 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 452 of Set 9 | eureka
# Processing Record 453 of Set 9 | sur
# Processing Record 454 of Set 9 | tomatlan
# Processing Record 455 of Set 9 | dingle
# Processing Record 456 of Set 9 | saint-pierre
# Processing Record 457 of Set 9 | grand-santi
# Processing Record 458 of Set 9 | nova olimpia
# Processing Record 460 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 461 of Set 10 | gazojak
# Processing Record 462 of Set 10 | port ellen
# City not found. Skipping...
# Processing Record 463 of Set 10 | ambon
# Processing Record 464 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 465 of Set 10 | chiplun
# Processing Record 466 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 467 of Set 10 | mormugao
# Processing Record 468 of Set 10 | marsh harbour
# Processing Record 469 of Set 10 | hirado
# Processing Record 470 of Set 10 | taksimo
# Processing Record 471 of Set 10 | grindavik
# Processing Record 472 of Set 10 | calvinia
# Processing Record 473 of Set 10 | kuching
# Processing Record 474 of Set 10 | port arthur
# Processing Record 475 of Set 10 | port-gentil
# Processing Record 476 of Set 10 | paytug
# City not found. Skipping...
# Processing Record 477 of Set 10 | henderson
# Processing Record 478 of Set 10 | svetlogorsk
# Processing Record 479 of Set 10 | constitucion
# Processing Record 480 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 481 of Set 10 | la romana
# Processing Record 482 of Set 10 | saint-joseph
# Processing Record 483 of Set 10 | krasnogvardeyskoye
# Processing Record 484 of Set 10 | coihaique
# Processing Record 485 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 486 of Set 10 | matadi
# Processing Record 487 of Set 10 | saiha
# Processing Record 488 of Set 10 | druzhnaya gorka
# Processing Record 489 of Set 10 | nome
# Processing Record 490 of Set 10 | sola
# Processing Record 491 of Set 10 | haines junction
# Processing Record 492 of Set 10 | kirakira
# Processing Record 493 of Set 10 | qasigiannguit
# Processing Record 494 of Set 10 | sawakin
# Processing Record 495 of Set 10 | gornopravdinsk
# Processing Record 496 of Set 10 | taunsa
# Processing Record 497 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 498 of Set 10 | la asuncion
# Processing Record 499 of Set 10 | jiazi
# Processing Record 500 of Set 10 | gondanglegi
# Processing Record 501 of Set 10 | san martin
# Processing Record 502 of Set 10 | wichian buri
# Processing Record 503 of Set 10 | melbu
# Processing Record 504 of Set 10 | nampa
# Processing Record 505 of Set 10 | kununurra
# Processing Record 506 of Set 10 | port hedland
# Processing Record 507 of Set 10 | shevchenkove
# Processing Record 508 of Set 10 | venice
# Processing Record 509 of Set 10 | kumluca
# Processing Record 511 of Set 11 | swan hill
# Processing Record 512 of Set 11 | vestmannaeyjar
# Processing Record 513 of Set 11 | basco
# Processing Record 514 of Set 11 | benguela
# Processing Record 515 of Set 11 | sao joao da barra
# Processing Record 516 of Set 11 | nizwa
# Processing Record 517 of Set 11 | qaqortoq
# Processing Record 518 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 519 of Set 11 | poum
# Processing Record 520 of Set 11 | san isidro
# Processing Record 521 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 522 of Set 11 | sao raimundo nonato
# Processing Record 523 of Set 11 | ostrovnoy
# Processing Record 524 of Set 11 | kalmunai
# Processing Record 525 of Set 11 | mugur-aksy
# Processing Record 526 of Set 11 | ugoofaaru
# Processing Record 527 of Set 11 | beitbridge
# Processing Record 528 of Set 11 | bull savanna
# Processing Record 529 of Set 11 | wiang sa
# Processing Record 530 of Set 11 | susangerd
# Processing Record 531 of Set 11 | malakal
# Processing Record 532 of Set 11 | creel
# Processing Record 533 of Set 11 | okahandja
# Processing Record 534 of Set 11 | mount gambier
# Processing Record 535 of Set 11 | codrington
# Processing Record 536 of Set 11 | takaungu
# Processing Record 537 of Set 11 | souillac
# Processing Record 538 of Set 11 | coolum beach
# Processing Record 539 of Set 11 | agadez
# Processing Record 540 of Set 11 | praia
# Processing Record 541 of Set 11 | nantucket
# Processing Record 542 of Set 11 | slonim
# Processing Record 543 of Set 11 | mingyue
# Processing Record 544 of Set 11 | wanlaweyn
# Processing Record 545 of Set 11 | ocozocoautla
# City not found. Skipping...
# Processing Record 546 of Set 11 | arbagar
# Processing Record 547 of Set 11 | guayaramerin
# Processing Record 548 of Set 11 | pachino
# Processing Record 549 of Set 11 | bilibino
# Processing Record 550 of Set 11 | montes claros
# Processing Record 551 of Set 11 | alyangula
# Processing Record 552 of Set 11 | sitges
# Processing Record 553 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 554 of Set 11 | aldan
# Processing Record 555 of Set 11 | safaqis
# City not found. Skipping...
# Processing Record 556 of Set 11 | fallon
# Processing Record 557 of Set 11 | gigmoto
# Processing Record 558 of Set 11 | port elizabeth
# Processing Record 559 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 560 of Set 11 | gibato
# Processing Record 562 of Set 12 | falkoping
# City not found. Skipping...
# Processing Record 563 of Set 12 | kamaishi
# Processing Record 564 of Set 12 | la palma
# Processing Record 565 of Set 12 | passos
# Processing Record 566 of Set 12 | sabha
# Processing Record 567 of Set 12 | sechura
# Processing Record 568 of Set 12 | husavik
# Processing Record 569 of Set 12 | laon
# Processing Record 570 of Set 12 | khrebtovaya
# Processing Record 571 of Set 12 | igarka
# Processing Record 572 of Set 12 | itoman
# Processing Record 573 of Set 12 | bartica
# Processing Record 574 of Set 12 | tahoua
# Processing Record 575 of Set 12 | tongchuan
# Processing Record 576 of Set 12 | staryy nadym
# Processing Record 577 of Set 12 | lamar
# Processing Record 578 of Set 12 | quatre cocos
# Processing Record 579 of Set 12 | santa catalina
# Processing Record 580 of Set 12 | lianzhou
# Processing Record 581 of Set 12 | ye
# City not found. Skipping...
# Processing Record 582 of Set 12 | sedniv
# Processing Record 583 of Set 12 | flagstaff
# Processing Record 584 of Set 12 | shafranovo
# Processing Record 585 of Set 12 | trairi
# Processing Record 586 of Set 12 | turki
# Processing Record 587 of Set 12 | ardatov
# Processing Record 588 of Set 12 | sovetskaya gavan
# Processing Record 589 of Set 12 | vangaindrano
# Processing Record 590 of Set 12 | shadrinsk
# Processing Record 591 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 592 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 593 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 594 of Set 12 | nepalganj
# City not found. Skipping...
# Processing Record 595 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 596 of Set 12 | mayo
# Processing Record 597 of Set 12 | usolye-sibirskoye
# Processing Record 598 of Set 12 | oksfjord
# Processing Record 599 of Set 12 | popondetta
# Processing Record 600 of Set 12 | coquimbo
# Processing Record 601 of Set 12 | vostok
# Processing Record 602 of Set 12 | la rioja
# Processing Record 603 of Set 12 | kapiri mposhi
# Processing Record 604 of Set 12 | yar-sale
# Processing Record 605 of Set 12 | tabuk
# Processing Record 606 of Set 12 | nouadhibou
# Processing Record 607 of Set 12 | verkhnyaya inta
# Processing Record 608 of Set 12 | sistranda
# Processing Record 609 of Set 12 | kieta
# Processing Record 610 of Set 12 | rock sound
# Processing Record 611 of Set 12 | nuuk
# Processing Record 613 of Set 13 | aktau
# Processing Record 614 of Set 13 | bilma
# Processing Record 615 of Set 13 | naryshkino
# Processing Record 616 of Set 13 | basoko
# Processing Record 617 of Set 13 | tynda
# Processing Record 618 of Set 13 | clyde river
# Processing Record 619 of Set 13 | nanga eboko
# Processing Record 620 of Set 13 | fugen
# Processing Record 621 of Set 13 | agirish
# Processing Record 622 of Set 13 | samdrup jongkhar
# Processing Record 623 of Set 13 | vilcun
# Processing Record 624 of Set 13 | roald
# Processing Record 625 of Set 13 | puerto escondido
# Processing Record 626 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 627 of Set 13 | avera
# Processing Record 628 of Set 13 | teahupoo
# Processing Record 629 of Set 13 | la ronge
# Processing Record 630 of Set 13 | banda aceh
# Processing Record 631 of Set 13 | yakeshi
# Processing Record 632 of Set 13 | faanui
# Processing Record 633 of Set 13 | touros
# Processing Record 634 of Set 13 | mtwara
# Processing Record 635 of Set 13 | shache
# Processing Record 636 of Set 13 | collie
# Processing Record 637 of Set 13 | mozhaysk
# Processing Record 638 of Set 13 | bay-khaak
# Processing Record 639 of Set 13 | comodoro rivadavia
# Processing Record 640 of Set 13 | bom jesus
# Processing Record 641 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 642 of Set 13 | hualmay
# Processing Record 643 of Set 13 | ferme-neuve
# Processing Record 644 of Set 13 | paoua
# Processing Record 645 of Set 13 | pandan
# Processing Record 646 of Set 13 | sharjah
# Processing Record 647 of Set 13 | warren
# Processing Record 648 of Set 13 | owo
# Processing Record 649 of Set 13 | corrientes
# Processing Record 650 of Set 13 | markovo
# Processing Record 651 of Set 13 | liwale
# Processing Record 652 of Set 13 | fuxin
# Processing Record 653 of Set 13 | kautokeino
# Processing Record 654 of Set 13 | balabac
# Processing Record 655 of Set 13 | gat
# Processing Record 656 of Set 13 | buchanan
# Processing Record 657 of Set 13 | chipinge
# Processing Record 658 of Set 13 | olaine
# Processing Record 659 of Set 13 | ketchikan
# Processing Record 660 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 661 of Set 13 | suntar
# Processing Record 662 of Set 13 | morondava
# Processing Record 664 of Set 14 | raudeberg
# Processing Record 665 of Set 14 | mackay
# Processing Record 666 of Set 14 | nhulunbuy
# Processing Record 667 of Set 14 | vanino
# Processing Record 668 of Set 14 | ionia
# Processing Record 669 of Set 14 | tulle
# Processing Record 670 of Set 14 | dahra
# Processing Record 671 of Set 14 | tecoanapa
# Processing Record 672 of Set 14 | margate
# Processing Record 673 of Set 14 | mahon
# Processing Record 674 of Set 14 | rio gallegos
# Processing Record 675 of Set 14 | killybegs
# Processing Record 676 of Set 14 | gravdal
# Processing Record 677 of Set 14 | dom pedrito
# Processing Record 678 of Set 14 | valparaiso
# Processing Record 679 of Set 14 | esperance
# Processing Record 680 of Set 14 | kulu
# Processing Record 681 of Set 14 | killarney
# Processing Record 682 of Set 14 | sunagawa
# Processing Record 683 of Set 14 | sulina
# Processing Record 684 of Set 14 | ushtobe
# Processing Record 685 of Set 14 | aksu
# Processing Record 686 of Set 14 | boulder
# Processing Record 687 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 688 of Set 14 | burns lake
# Processing Record 689 of Set 14 | isangel
# Processing Record 690 of Set 14 | bose
# Processing Record 691 of Set 14 | gold coast
# Processing Record 692 of Set 14 | ouegoa
# Processing Record 693 of Set 14 | kpandu
# Processing Record 694 of Set 14 | spring hill
# Processing Record 695 of Set 14 | angoram
# Processing Record 696 of Set 14 | inhambane
# Processing Record 697 of Set 14 | kaeo
# Processing Record 698 of Set 14 | tongliao
# Processing Record 699 of Set 14 | vrangel
# Processing Record 700 of Set 14 | belaya gora
# Processing Record 701 of Set 14 | progreso
# Processing Record 702 of Set 14 | sarab
# Processing Record 703 of Set 14 | nerja
# Processing Record 704 of Set 14 | kurumkan
# Processing Record 705 of Set 14 | sawtell
# Processing Record 706 of Set 14 | kovdor
# Processing Record 707 of Set 14 | pedernales
# Processing Record 708 of Set 14 | virginia beach
# Processing Record 709 of Set 14 | colares
# Processing Record 710 of Set 14 | komsomolskiy
# Processing Record 711 of Set 14 | longfeng
# Processing Record 712 of Set 14 | mwinilunga
# Processing Record 713 of Set 14 | san vicente
# Processing Record 715 of Set 15 | vallenar
# Processing Record 716 of Set 15 | coruripe
# Processing Record 717 of Set 15 | port lincoln
# Processing Record 718 of Set 15 | teofilo otoni
# Processing Record 719 of Set 15 | luena
# Processing Record 720 of Set 15 | vychegodskiy
# Processing Record 721 of Set 15 | pedra
# Processing Record 722 of Set 15 | al
# City not found. Skipping...
# Processing Record 723 of Set 15 | port hardy
# Processing Record 724 of Set 15 | dalbandin
# Processing Record 725 of Set 15 | kristiinankaupunki
# Processing Record 726 of Set 15 | zyryanka
# Processing Record 727 of Set 15 | jos
# Processing Record 728 of Set 15 | kawhia
# Processing Record 729 of Set 15 | ust-kuyga
# Processing Record 730 of Set 15 | surskoye
# Processing Record 731 of Set 15 | korla
# Processing Record 732 of Set 15 | nicoya
# Processing Record 733 of Set 15 | doctor arroyo
# Processing Record 734 of Set 15 | fukue
# Processing Record 735 of Set 15 | los llanos de aridane
# Processing Record 736 of Set 15 | fethiye
# Processing Record 737 of Set 15 | bayir
# Processing Record 738 of Set 15 | camana
# Processing Record 739 of Set 15 | ambilobe
# Processing Record 740 of Set 15 | saint pete beach
# Processing Record 741 of Set 15 | shiraz
# Processing Record 742 of Set 15 | sisimiut
# Processing Record 743 of Set 15 | yorosso
# Processing Record 744 of Set 15 | alugan
# Processing Record 745 of Set 15 | kloulklubed
# Processing Record 746 of Set 15 | verkhne-katunskoye
# City not found. Skipping...
# Processing Record 747 of Set 15 | chiredzi
# Processing Record 748 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 749 of Set 15 | buckeye
# Processing Record 750 of Set 15 | west wendover
# Processing Record 751 of Set 15 | safranbolu
# Processing Record 752 of Set 15 | athabasca
# Processing Record 753 of Set 15 | ucluelet
# Processing Record 754 of Set 15 | karachev
# Processing Record 755 of Set 15 | ust-maya
# Processing Record 756 of Set 15 | harper
# Processing Record 757 of Set 15 | klyuchi
# Processing Record 758 of Set 15 | ascension
# Processing Record 759 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 760 of Set 15 | galle
# Processing Record 761 of Set 15 | fort nelson
# Processing Record 762 of Set 15 | juneau
# Processing Record 763 of Set 15 | port blair
# Processing Record 764 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 766 of Set 16 | ayan
# Processing Record 767 of Set 16 | rio verde de mato grosso
# Processing Record 768 of Set 16 | jasper
# Processing Record 769 of Set 16 | pizarro
# Processing Record 770 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 771 of Set 16 | alta floresta
# Processing Record 772 of Set 16 | abu dhabi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kondinskoye      RU  59.6481   67.4100     33.85        94         100
# 1  Bambous Virieux      MU -20.3428   57.7575     81.00        75          17
# 2            Sitka      US  57.0531 -135.3300     39.20        87          90
# 3         Kot Diji      PK  27.3427   68.7083     84.20        45           0
# 4            Kapaa      US  22.0752 -159.3190     75.20        64          90
# 5       Chokurdakh      RU  70.6333  147.9167    -29.85       100          49
# 6        Jamestown      US  42.0970  -79.2353     55.00        35           1
# 7       Butaritari      KI   3.0707  172.7902     81.68        80         100
# 8           Albany      US  42.6001  -73.9662     59.00        24          14
# 9     Punta Arenas      CL -53.1500  -70.9167     50.00        53          40
#
#    Wind Speed       Description
# 0        9.91   overcast clouds
# 1        5.99        light rain
# 2        4.61        light rain
# 3        7.11              haze
# 4       17.27   overcast clouds
# 5        4.34  scattered clouds
# 6       17.27         clear sky
# 7       14.25   overcast clouds
# 8        1.99        few clouds
# 9       21.85  scattered clouds

# %%
# Export the dataframe to a csv file.
output_data_file = "WeatherPy_database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
